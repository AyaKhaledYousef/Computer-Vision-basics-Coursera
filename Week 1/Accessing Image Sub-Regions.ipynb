# %%
import matplotlib.pyplot as plt
img= plt.imread('cameraman.png')
plt.imshow(img)

# %%
R= plt.imread('ROI.png')
plt.imshow(R)

# %%
ROI1 = img[5:40, 3:40]
plt.imshow(ROI1)

# %%
ROI2 = img[210:300, 210:300]
plt.imshow(ROI2)

# %%
SSD=
